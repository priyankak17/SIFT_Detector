# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankak17/SIFT_Detector/blob/main/SIFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img_path = '/content/f.jpg'

# %%
img = mpimg.imread(img_path)
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
sift = cv2.SIFT_create()

# %%
keypoints, descriptors = sift.detectAndCompute(img, None)

# %%
img_keypoints = cv2.drawKeypoints(gray_image, keypoints,img, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
#Display the image with keypoints
plt.imshow(img_keypoints)
plt.axis('off')  # Optional: Turn off axis labels and ticks
plt.show()
